# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
cities = ["New Orleans", "Milwaukee", "Omaha", "Pittsburgh", "Toledo"]
bars_in_cities = [8.6, 8.5, 8.3, 7.9, 7.2]
x_axis = np.arange(len(bars_in_cities))

# %%
# Create a bar chart based upon the above data
plt.bar(x_axis,bars_in_cities,color="r",alpha=0.5, align="center")
#plt.bar(cities,x_axis,color= "b", alpha=0.5, align="center")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 5 artists>

# %%
# Create the ticks for our bar chart's x axis
tick_locations = [values for values in x_axis]
plt.xticks(tick_locations,["New Orleans", "Milwaukee", "Omaha", "Pittsburgh", "Toledo"])
# Out:
# ([<matplotlib.axis.XTick at 0x169feba5f40>,
#   <matplotlib.axis.XTick at 0x169feba5be0>,
#   <matplotlib.axis.XTick at 0x169febee4f0>,
#   <matplotlib.axis.XTick at 0x169fe921a60>,
#   <matplotlib.axis.XTick at 0x169fe921e80>],
#  [Text(0, 0, 'New Orleans'),
#   Text(1, 0, 'Milwaukee'),
#   Text(2, 0, 'Omaha'),
#   Text(3, 0, 'Pittsburgh'),
#   Text(4, 0, 'Toledo')])

# %%
# Set the limits of the x axis
plt.xlim(-0.45,len(x_axis)-0.55)
# Out:
# (-0.45, 4.45)

# %%
# Set the limits of the y axis
plt.ylim(0,max(bars_in_cities)+0.5)
# Out:
# (0.0, 9.1)

# %%
# Give the chart a title, x label, and y label
plt.title("Bars in Cities")
plt.xlabel("Cities")
plt.ylabel("NO. of bars")
# Out:
# Text(69.90277777777779, 0.5, 'NO. of bars')

# %%
# Save an image of the chart and print it to the screen
plt.savefig("../Images/bar_cities.png")

# %%
plt.show()
